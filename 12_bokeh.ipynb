# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ffa0a5e0-8812-40a5-a962-f7440013aca7">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure, output_file, show

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')
p = figure(title = 'test_flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.circle(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="a2828971-4ea3-40a4-827d-5123b1c4f710" data-root-id="p1095" style="display: contents;"></div>

# %%
output_file('test.html')
p = figure(title = 'test_flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.line(flowers['petal_length'], flowers['petal_width'])
show(p)
# Out:
#   <div id="dee0d9db-07cf-4cca-a2ab-6919d970b816" data-root-id="p1143" style="display: contents;"></div>

# %%
x = [1,2,3,4]
y = [3,6,2,6]

p = figure(title="line_chart")
p.line(x,y)
show(p)
# Out:
#   <div id="aa8721c0-9581-471b-8430-0283bf7fc081" data-root-id="p1191" style="display: contents;"></div>

# %%
x = [1,2,3,4]
y = [3,6,2,6]

p = figure(title="line_chart")
p.scatter(x,y,size = 20,fill_color='r',legend_label="this is my data")
show(p)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : fill_color='r' [no close matches] {renderer: GlyphRenderer(id='p1320', ...)}
#   <div id="f518e6ed-b6d6-4fa9-abc8-87280debfa1e" data-root-id="p1279" style="display: contents;"></div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : fill_color='r' [no close matches] {renderer: GlyphRenderer(id='p1320', ...)}
